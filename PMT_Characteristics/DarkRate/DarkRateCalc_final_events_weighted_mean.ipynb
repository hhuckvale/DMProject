# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import re
from scipy.optimize import curve_fit
from math import floor, log10

# %%
"""
Cleaned CSV has columns:

            'baseline': mean_b_array,
            'sd_baseline': sigma_b_array,
            'amplitude': all_amplitudes,
            'peak_time': all_peak_times,
            'FWHM': all_FWHM,
            't1_of_FWHM': all_t1,
            't2_of_FWHM': all_t2,
            'time_above_15sigma': all_time_above_15thresh,
            'first_15sigma_crossing': all_first_15crossing,
            'second_15sigma_crossing': all_second_15crossing,
            'time_above_10sigma': all_time_above_10thresh,
            'first_10sigma_crossing': all_first_10crossing,
            'second_10sigma_crossing': all_second_10crossing,
            'time_above_5sigma': all_time_above_5thresh,
            'first_5sigma_crossing': all_first_5crossing,
            'second_5sigma_crossing': all_second_5crossing,
            'integral_pC': all_integrals_picocharge,
            'peaks_over_15sigma_threshold': number_of_maxima_all,
            'event_timestamps' : event_timestamps[:-1]
"""
# Out:
# "\nCleaned CSV has columns:\n\n            'baseline': mean_b_array,\n            'sd_baseline': sigma_b_array,\n            'amplitude': all_amplitudes,\n            'peak_time': all_peak_times,\n            'FWHM': all_FWHM,\n            't1_of_FWHM': all_t1,\n            't2_of_FWHM': all_t2,\n            'time_above_15sigma': all_time_above_15thresh,\n            'first_15sigma_crossing': all_first_15crossing,\n            'second_15sigma_crossing': all_second_15crossing,\n            'time_above_10sigma': all_time_above_10thresh,\n            'first_10sigma_crossing': all_first_10crossing,\n            'second_10sigma_crossing': all_second_10crossing,\n            'time_above_5sigma': all_time_above_5thresh,\n            'first_5sigma_crossing': all_first_5crossing,\n            'second_5sigma_crossing': all_second_5crossing,\n            'integral_pC': all_integrals_picocharge,\n            'peaks_over_15sigma_threshold': number_of_maxima_all,\n            'event_timestamps' : event_timestamps[:-1]\n"

# %%
"""
Need to find an average over three trials.
Some trials end up having very low numbers of events (super noisy data collection), these shouldn't be considered.
Need to plot dark rate against voltage. 
Try using the naming convention to loop over events and plot them? 

Name: date+note+voltage+10000+trialnumber+lights+clean.csv

"""
# Out:
# "\nNeed to find an average over three trials.\nSome trials end up having very low numbers of events (super noisy data collection), these shouldn't be considered.\nNeed to plot dark rate against voltage. \nTry using the naming convention to loop over events and plot them? \n\nName: date+note+voltage+10000+trialnumber+lights+clean.csv\n\n"

# %%
#15sigma threshold

#eliminate files with less than 1000 events in after cleaning.

allfiles = glob.glob('PMT1_Cleaned/*cleaned.csv')

enough_events = []

for f in allfiles:
    df = pd.read_csv(f)
    if len(df)<1000:
        print(f"Discarding {f}, only {len(df)} events after cleaning")
        continue
    enough_events.append(f)
# Out:
# Discarding PMT1_Cleaned\131125_darkrate_1800_10000_1_on_processed_threshold14_cleaned.csv, only 851 events after cleaning
# Discarding PMT1_Cleaned\131125_darkrate_1800_10000_1_on_processed_threshold15_cleaned.csv, only 848 events after cleaning
# Discarding PMT1_Cleaned\131125_darkrate_1800_10000_1_on_processed_threshold16_cleaned.csv, only 845 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_2_off_processed_threshold14_cleaned.csv, only 949 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_2_off_processed_threshold15_cleaned.csv, only 949 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_2_off_processed_threshold16_cleaned.csv, only 946 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_3_off_processed_threshold14_cleaned.csv, only 272 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_3_off_processed_threshold15_cleaned.csv, only 271 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_3_off_processed_threshold16_cleaned.csv, only 271 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_3_on_processed_threshold14_cleaned.csv, only 766 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_3_on_processed_threshold15_cleaned.csv, only 764 events after cleaning
# Discarding PMT1_Cleaned\141125_darkrate_1850_10000_3_on_processed_threshold16_cleaned.csv, only 762 events after cleaning

# %%
#15sigma threshold

# first find the place value of the smallest digit in the timesteps:
def last_digit_place_value(x):
    """
    Returns the place value of the last digit in x.
    Example: 0.1234 -> 0.0001, 15.20 -> 0.01, 5000 -> 1000
    """
    s = str(x)

    # Handle scientific notation
    if 'e' in s.lower():
        s = format(float(x), '.15f').rstrip('0').rstrip('.')

    if '.' in s:
        frac_part = s.split('.')[1]
        return 10 ** (-len(frac_part))
    else:
        trailing_zeros = len(s) - len(s.rstrip('0'))
        return 10 ** trailing_zeros
    
#calculate dark rate for each csv in enough_events and their errors
dark_rates = {}
raw_storage = {}
for file in enough_events:
    df = pd.read_csv(file)
    timestamp_column = df['event_timestamps']
    timetaken = timestamp_column.iloc[-1] - timestamp_column.iloc[0]
    amplitude_column = df['amplitude']
    dark_rate = len(amplitude_column) / timetaken

    if dark_rate > 15000: 
        print(f"Discarding {file} due to unusual dark rate = {dark_rate:.3f}Hz")
        continue
# calculate errors
    N = len(amplitude_column)
    t_last_err = 0.5 * last_digit_place_value(timestamp_column.iloc[-1])
    t_first_err = 0.5 * last_digit_place_value(timestamp_column.iloc[0])
    t_err = np.sqrt(t_last_err**2 + t_first_err**2)
    DR_err = np.sqrt((np.sqrt(N)/timetaken)**2 + ((N*t_err)/timetaken**2)**2)
    
    print(DR_err)

    match = re.search(r"darkrate_(\d+)_10000_(\d+)_(on|off)_processed_threshold(\d+).*", file)
    if not match:
        continue
    
    voltage = int(match.group(1))
    light_state = match.group(3)
    thresh = int(match.group(4)) # e.g., 11

    raw_storage.setdefault(thresh, {}).setdefault(voltage, {}).setdefault(light_state, []).append((dark_rate, DR_err))


    dark_rates[file] = (dark_rate, DR_err)
    print(f"{file} has dark rate = {dark_rate:.3f} Hz")
    print(f"{file} ",'amount of events in clean files', len(amplitude_column))

#PUT ERROR PROPAGATION HERE FOR EACH RATE
# Out:
# 0.5483211356598896
# PMT1_Cleaned\131125_darkrate_1750_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 44.855 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 6692
# 0.5468853616960709
# PMT1_Cleaned\131125_darkrate_1750_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 44.621 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 6657
# 0.5445389984144565
# PMT1_Cleaned\131125_darkrate_1750_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 44.239 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 6600
# 1.0340130292650098
# PMT1_Cleaned\131125_darkrate_1750_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 46.931 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 2060
# 1.032416229964168
# PMT1_Cleaned\131125_darkrate_1750_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 46.779 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 2053
# 1.0258579368692933
# PMT1_Cleaned\131125_darkrate_1750_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 46.186 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 2027
# 0.5952968214474272
# PMT1_Cleaned\131125_darkrate_1750_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 43.680 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 5384
# 0.5935805471048902
# PMT1_Cleaned\131125_darkrate_1750_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 43.429 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 5353
# 0.5908575587437179
# PMT1_Cleaned\131125_darkrate_1750_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 43.031 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 5304
# 0.5502536117239506
# PMT1_Cleaned\131125_darkrate_1750_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 44.872 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 6650
# 0.5481395556047418
# PMT1_Cleaned\131125_darkrate_1750_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 44.528 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 6599
# 0.5449739815483629
# PMT1_Cleaned\131125_darkrate_1750_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 44.015 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 6523
# 0.5871891645649958
# PMT1_Cleaned\131125_darkrate_1750_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 47.326 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 6496
# 0.5867370283891008
# PMT1_Cleaned\131125_darkrate_1750_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 47.253 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 6486
# 0.5848796158477785
# PMT1_Cleaned\131125_darkrate_1750_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 46.955 Hz
# PMT1_Cleaned\131125_darkrate_1750_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 6445
# 0.8901841169584033
# PMT1_Cleaned\131125_darkrate_1800_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 83.350 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 8767
# 0.8895238747611381
# PMT1_Cleaned\131125_darkrate_1800_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 83.226 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 8754
# 0.8876929488924101
# PMT1_Cleaned\131125_darkrate_1800_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 82.884 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 8718
# 0.8947894589086113
# PMT1_Cleaned\131125_darkrate_1800_10000_2_off_processed_threshold14_cleaned.csv has dark rate = 84.120 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_2_off_processed_threshold14_cleaned.csv  amount of events in clean files 8838
# 0.8937764511583767
# PMT1_Cleaned\131125_darkrate_1800_10000_2_off_processed_threshold15_cleaned.csv has dark rate = 83.929 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_2_off_processed_threshold15_cleaned.csv  amount of events in clean files 8818
# 0.8910355776273825
# PMT1_Cleaned\131125_darkrate_1800_10000_2_off_processed_threshold16_cleaned.csv has dark rate = 83.415 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_2_off_processed_threshold16_cleaned.csv  amount of events in clean files 8764
# 0.9602795746814778
# PMT1_Cleaned\131125_darkrate_1800_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 88.819 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 8555
# 0.9592688129053053
# PMT1_Cleaned\131125_darkrate_1800_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 88.632 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 8537
# 0.9578069405867214
# PMT1_Cleaned\131125_darkrate_1800_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 88.363 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 8511
# 0.887105850583183
# PMT1_Cleaned\131125_darkrate_1800_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 83.043 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 8763
# 0.8862956155922717
# PMT1_Cleaned\131125_darkrate_1800_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 82.891 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 8747
# 0.8836572211414273
# PMT1_Cleaned\131125_darkrate_1800_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 82.398 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 8695
# 1.484025043406658
# PMT1_Cleaned\131125_darkrate_1800_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 83.251 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 3147
# 1.4778819425052547
# PMT1_Cleaned\131125_darkrate_1800_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 82.563 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 3121
# 1.469571832776404
# PMT1_Cleaned\131125_darkrate_1800_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 81.637 Hz
# PMT1_Cleaned\131125_darkrate_1800_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 3086
# 1.6664003953835165
# PMT1_Cleaned\141125_darkrate_1850_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 108.598 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 4247
# 1.6656154681636217
# PMT1_Cleaned\141125_darkrate_1850_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 108.495 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 4243
# 1.6644373832809969
# PMT1_Cleaned\141125_darkrate_1850_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 108.342 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 4237
# 3.000081580597062
# PMT1_Cleaned\141125_darkrate_1850_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 105.217 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 1230
# 2.99886178726321
# PMT1_Cleaned\141125_darkrate_1850_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 105.131 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 1229
# 2.9939776443030417
# PMT1_Cleaned\141125_darkrate_1850_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 104.789 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 1225
# 3.061294158809618
# PMT1_Cleaned\141125_darkrate_1850_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 97.961 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 1024
# 3.0538111504076135
# PMT1_Cleaned\141125_darkrate_1850_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 97.483 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 1019
# 3.0493125309992513
# PMT1_Cleaned\141125_darkrate_1850_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 97.196 Hz
# PMT1_Cleaned\141125_darkrate_1850_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 1016
# 1.3558309584778192
# PMT1_Cleaned\141125_darkrate_1900_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 128.711 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 9012
# 1.3559061800351175
# PMT1_Cleaned\141125_darkrate_1900_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 128.725 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 9013
# 1.3557557327469945
# PMT1_Cleaned\141125_darkrate_1900_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 128.697 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 9011
# 1.220799231369889
# PMT1_Cleaned\141125_darkrate_1900_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 116.130 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 9049
# 1.2209341337661648
# PMT1_Cleaned\141125_darkrate_1900_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 116.156 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 9051
# 1.2202594726471987
# PMT1_Cleaned\141125_darkrate_1900_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 116.027 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 9041
# 0.8768374503852951
# PMT1_Cleaned\141125_darkrate_1900_10000_2_off_processed_threshold14_cleaned.csv has dark rate = 83.198 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_2_off_processed_threshold14_cleaned.csv  amount of events in clean files 9003
# 0.8768374503852951
# PMT1_Cleaned\141125_darkrate_1900_10000_2_off_processed_threshold15_cleaned.csv has dark rate = 83.198 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_2_off_processed_threshold15_cleaned.csv  amount of events in clean files 9003
# 0.8768374503852951
# PMT1_Cleaned\141125_darkrate_1900_10000_2_off_processed_threshold16_cleaned.csv has dark rate = 83.198 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_2_off_processed_threshold16_cleaned.csv  amount of events in clean files 9003
# 1.4278709494436184
# PMT1_Cleaned\141125_darkrate_1900_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 135.993 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 9071
# 1.4279496525413466
# PMT1_Cleaned\141125_darkrate_1900_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 136.008 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 9072
# 1.4279496525413466
# PMT1_Cleaned\141125_darkrate_1900_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 136.008 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 9072
# 0.938144919632137
# PMT1_Cleaned\141125_darkrate_1900_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 87.424 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 8684
# 0.937550558500283
# PMT1_Cleaned\141125_darkrate_1900_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 87.313 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 8673
# 0.9372262026495446
# PMT1_Cleaned\141125_darkrate_1900_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 87.253 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 8667
# 1.4885447013311492
# PMT1_Cleaned\141125_darkrate_1900_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 141.427 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 9027
# 1.4885447013311492
# PMT1_Cleaned\141125_darkrate_1900_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 141.427 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 9027
# 1.4873899593266529
# PMT1_Cleaned\141125_darkrate_1900_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 141.208 Hz
# PMT1_Cleaned\141125_darkrate_1900_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 9013
# 1.8810581051489377
# PMT1_Cleaned\141125_darkrate_1950_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 109.377 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 3381
# 1.881614384358244
# PMT1_Cleaned\141125_darkrate_1950_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 109.441 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 3383
# 1.8807799038451685
# PMT1_Cleaned\141125_darkrate_1950_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 109.344 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 3380
# 1.0219101487978057
# PMT1_Cleaned\141125_darkrate_1950_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 96.141 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 8851
# 1.0221987506134944
# PMT1_Cleaned\141125_darkrate_1950_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 96.195 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 8856
# 1.0224295734121038
# PMT1_Cleaned\141125_darkrate_1950_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 96.239 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 8860
# 1.2822942095117487
# PMT1_Cleaned\141125_darkrate_1950_10000_2_off_processed_threshold14_cleaned.csv has dark rate = 121.433 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_2_off_processed_threshold14_cleaned.csv  amount of events in clean files 8968
# 1.2822942095117487
# PMT1_Cleaned\141125_darkrate_1950_10000_2_off_processed_threshold15_cleaned.csv has dark rate = 121.433 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_2_off_processed_threshold15_cleaned.csv  amount of events in clean files 8968
# 1.2822942095117487
# PMT1_Cleaned\141125_darkrate_1950_10000_2_off_processed_threshold16_cleaned.csv has dark rate = 121.433 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_2_off_processed_threshold16_cleaned.csv  amount of events in clean files 8968
# 1.2535925007640283
# PMT1_Cleaned\141125_darkrate_1950_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 116.584 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 8649
# 1.2539548002718277
# PMT1_Cleaned\141125_darkrate_1950_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 116.652 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 8654
# 1.2541721297399848
# PMT1_Cleaned\141125_darkrate_1950_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 116.692 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 8657
# 1.134508767445677
# PMT1_Cleaned\141125_darkrate_1950_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 106.849 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 8870
# 1.134892414675528
# PMT1_Cleaned\141125_darkrate_1950_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 106.921 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 8876
# 1.1352120216588772
# PMT1_Cleaned\141125_darkrate_1950_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 106.981 Hz
# PMT1_Cleaned\141125_darkrate_1950_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 8881
# 1.849306862290141
# PMT1_Cleaned\141125_darkrate_2000_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 173.608 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 8813
# 1.849306862290141
# PMT1_Cleaned\141125_darkrate_2000_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 173.608 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 8813
# 1.8490970118653756
# PMT1_Cleaned\141125_darkrate_2000_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 173.569 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 8811
# 1.8478477577332886
# PMT1_Cleaned\141125_darkrate_2000_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 165.895 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 8060
# 1.848306223875496
# PMT1_Cleaned\141125_darkrate_2000_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 165.977 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 8064
# 1.8478477577332886
# PMT1_Cleaned\141125_darkrate_2000_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 165.895 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 8060
# 1.5701167930439124
# PMT1_Cleaned\141125_darkrate_2000_10000_2_off_processed_threshold14_cleaned.csv has dark rate = 146.602 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_2_off_processed_threshold14_cleaned.csv  amount of events in clean files 8718
# 1.569846618940038
# PMT1_Cleaned\141125_darkrate_2000_10000_2_off_processed_threshold15_cleaned.csv has dark rate = 146.552 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_2_off_processed_threshold15_cleaned.csv  amount of events in clean files 8715
# 1.5697565505720277
# PMT1_Cleaned\141125_darkrate_2000_10000_2_off_processed_threshold16_cleaned.csv has dark rate = 146.535 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_2_off_processed_threshold16_cleaned.csv  amount of events in clean files 8714
# 1.6896928118306351
# PMT1_Cleaned\141125_darkrate_2000_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 158.408 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 8789
# 1.6886351010466547
# PMT1_Cleaned\141125_darkrate_2000_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 158.210 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 8778
# 1.6877692082791589
# PMT1_Cleaned\141125_darkrate_2000_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 158.048 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 8769
# 1.35269698479263
# PMT1_Cleaned\141125_darkrate_2000_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 125.050 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 8546
# 1.3527761245899652
# PMT1_Cleaned\141125_darkrate_2000_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 125.064 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 8547
# 1.352617840364935
# PMT1_Cleaned\141125_darkrate_2000_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 125.035 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 8545
# 1.7112885241403561
# PMT1_Cleaned\141125_darkrate_2000_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 160.223 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 8766
# 1.7117765017156854
# PMT1_Cleaned\141125_darkrate_2000_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 160.314 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 8771
# 1.7114837318663254
# PMT1_Cleaned\141125_darkrate_2000_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 160.259 Hz
# PMT1_Cleaned\141125_darkrate_2000_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 8768
# 0.6989032290528294
# PMT1_Cleaned\241125_darkrate_1800_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 66.770 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 9127
# 0.6982137107636747
# PMT1_Cleaned\241125_darkrate_1800_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 66.638 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 9109
# 0.6967174134854451
# PMT1_Cleaned\241125_darkrate_1800_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 66.353 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 9070
# 0.7047643267218227
# PMT1_Cleaned\241125_darkrate_1800_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 67.492 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 9171
# 0.704456871444143
# PMT1_Cleaned\241125_darkrate_1800_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 67.433 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 9163
# 0.7039954367626815
# PMT1_Cleaned\241125_darkrate_1800_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 67.345 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 9151
# 0.6917523218432352
# PMT1_Cleaned\241125_darkrate_1800_10000_2_off_processed_threshold14_cleaned.csv has dark rate = 65.938 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_2_off_processed_threshold14_cleaned.csv  amount of events in clean files 9086
# 0.6908381113268102
# PMT1_Cleaned\241125_darkrate_1800_10000_2_off_processed_threshold15_cleaned.csv has dark rate = 65.764 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_2_off_processed_threshold15_cleaned.csv  amount of events in clean files 9062
# 0.6890442688343869
# PMT1_Cleaned\241125_darkrate_1800_10000_2_off_processed_threshold16_cleaned.csv has dark rate = 65.423 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_2_off_processed_threshold16_cleaned.csv  amount of events in clean files 9015
# 0.7020769441525723
# PMT1_Cleaned\241125_darkrate_1800_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 67.187 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 9158
# 0.7013098982072276
# PMT1_Cleaned\241125_darkrate_1800_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 67.040 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 9138
# 0.7006572489201316
# PMT1_Cleaned\241125_darkrate_1800_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 66.916 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 9121
# 0.7028294218406325
# PMT1_Cleaned\241125_darkrate_1800_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 67.108 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 9117
# 0.702096684994877
# PMT1_Cleaned\241125_darkrate_1800_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 66.968 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 9098
# 0.7007449009219306
# PMT1_Cleaned\241125_darkrate_1800_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 66.711 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 9063
# 0.7061698448043094
# PMT1_Cleaned\241125_darkrate_1800_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 66.915 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 8979
# 0.7052254514097782
# PMT1_Cleaned\241125_darkrate_1800_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 66.736 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 8955
# 0.7038459396347687
# PMT1_Cleaned\241125_darkrate_1800_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 66.475 Hz
# PMT1_Cleaned\241125_darkrate_1800_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 8920
# 1.6185275876988434
# PMT1_Cleaned\241125_darkrate_1850_10000_1_off_processed_threshold14_cleaned.csv has dark rate = 79.423 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_1_off_processed_threshold14_cleaned.csv  amount of events in clean files 2408
# 1.6185275876988434
# PMT1_Cleaned\241125_darkrate_1850_10000_1_off_processed_threshold15_cleaned.csv has dark rate = 79.423 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_1_off_processed_threshold15_cleaned.csv  amount of events in clean files 2408
# 1.6178553020674724
# PMT1_Cleaned\241125_darkrate_1850_10000_1_off_processed_threshold16_cleaned.csv has dark rate = 79.357 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_1_off_processed_threshold16_cleaned.csv  amount of events in clean files 2406
# 0.9797893512216024
# PMT1_Cleaned\241125_darkrate_1850_10000_1_on_processed_threshold14_cleaned.csv has dark rate = 78.847 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_1_on_processed_threshold14_cleaned.csv  amount of events in clean files 6476
# 0.9781238188541127
# PMT1_Cleaned\241125_darkrate_1850_10000_1_on_processed_threshold15_cleaned.csv has dark rate = 78.579 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_1_on_processed_threshold15_cleaned.csv  amount of events in clean files 6454
# 0.9756959558015167
# PMT1_Cleaned\241125_darkrate_1850_10000_1_on_processed_threshold16_cleaned.csv has dark rate = 78.190 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_1_on_processed_threshold16_cleaned.csv  amount of events in clean files 6422
# 0.7918662210911022
# PMT1_Cleaned\241125_darkrate_1850_10000_2_off_processed_threshold14_cleaned.csv has dark rate = 75.277 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_2_off_processed_threshold14_cleaned.csv  amount of events in clean files 9037
# 0.7903312977229648
# PMT1_Cleaned\241125_darkrate_1850_10000_2_off_processed_threshold15_cleaned.csv has dark rate = 74.986 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_2_off_processed_threshold15_cleaned.csv  amount of events in clean files 9002
# 0.7883094246761413
# PMT1_Cleaned\241125_darkrate_1850_10000_2_off_processed_threshold16_cleaned.csv has dark rate = 74.603 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_2_off_processed_threshold16_cleaned.csv  amount of events in clean files 8956
# 0.8240498555118481
# PMT1_Cleaned\241125_darkrate_1850_10000_2_on_processed_threshold14_cleaned.csv has dark rate = 79.434 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_2_on_processed_threshold14_cleaned.csv  amount of events in clean files 9292
# 0.8236506817378079
# PMT1_Cleaned\241125_darkrate_1850_10000_2_on_processed_threshold15_cleaned.csv has dark rate = 79.357 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_2_on_processed_threshold15_cleaned.csv  amount of events in clean files 9283
# 0.8228961585246337
# PMT1_Cleaned\241125_darkrate_1850_10000_2_on_processed_threshold16_cleaned.csv has dark rate = 79.212 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_2_on_processed_threshold16_cleaned.csv  amount of events in clean files 9266
# 0.7957430845881796
# PMT1_Cleaned\241125_darkrate_1850_10000_3_off_processed_threshold14_cleaned.csv has dark rate = 75.499 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_3_off_processed_threshold14_cleaned.csv  amount of events in clean files 9002
# 0.7922437381951056
# PMT1_Cleaned\241125_darkrate_1850_10000_3_off_processed_threshold15_cleaned.csv has dark rate = 74.837 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_3_off_processed_threshold15_cleaned.csv  amount of events in clean files 8923
# 0.7886396790246331
# PMT1_Cleaned\241125_darkrate_1850_10000_3_off_processed_threshold16_cleaned.csv has dark rate = 74.157 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_3_off_processed_threshold16_cleaned.csv  amount of events in clean files 8842
# 0.8159258099087547
# PMT1_Cleaned\241125_darkrate_1850_10000_3_on_processed_threshold14_cleaned.csv has dark rate = 78.727 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_3_on_processed_threshold14_cleaned.csv  amount of events in clean files 9310
# 0.8156628483689471
# PMT1_Cleaned\241125_darkrate_1850_10000_3_on_processed_threshold15_cleaned.csv has dark rate = 78.677 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_3_on_processed_threshold15_cleaned.csv  amount of events in clean files 9304
# 0.8147418146128552
# PMT1_Cleaned\241125_darkrate_1850_10000_3_on_processed_threshold16_cleaned.csv has dark rate = 78.499 Hz
# PMT1_Cleaned\241125_darkrate_1850_10000_3_on_processed_threshold16_cleaned.csv  amount of events in clean files 9283

# %%
#15sigma threshold
#plot dark rate against voltage for lights on and lights off on the same plot.

#these will be lists of voltages with their corresponding dark rates. eg. {1750: [213,453,241], 2000: [542,622,315]}
lights_on = {} 
lights_off = {}

central_t = 15
low_t = 14
high_t = 16

def get_weighted_stats(thresh, volt, state):
    data = raw_storage.get(thresh, {}).get(volt, {}).get(state, [])
    if not data: return None, None
    
    rates, errs = zip(*data)
    rates, errs = np.array(rates), np.array(errs)
    weights = 1 / (errs**2)
    
    w_mean = np.sum(weights * rates) / np.sum(weights) # weighted mean
    w_err = np.sqrt(1 / np.sum(weights)) # weighted error
    return w_mean, w_err

# Process all voltages found in the central threshold
all_voltages = []
all_voltages = sorted(raw_storage.get(central_t, {}).keys())

for voltage in all_voltages:
    for state in ['on', 'off']:
        # Get Weighted Mean and Stat Error for Threshold 11 (central voltage)
        mean_cen, err_cen = get_weighted_stats(central_t, voltage, state)
        if mean_cen is None: continue
        
        # Get Weighted Means for Threshold 10 and 12
        mean_low, _ = get_weighted_stats(low_t, voltage, state)
        mean_high, _ = get_weighted_stats(high_t, voltage, state)
        
        # 3. Calculate Systematic Error: |Rate_high - Rate_low| / 2
        if mean_low is not None and mean_high is not None:
            sys_err = abs(mean_high - mean_low) / 2
        else:
            sys_err = 0.0 # Default if bounds are missing

        # 4. Combine Stat and Sys Error in Quadrature
        total_err = np.sqrt(err_cen**2 + sys_err**2)
        
        # Store in your original lights_on / lights_off dictionaries
        if state == 'on':
            lights_on[voltage] = (mean_cen, total_err)
        else:
            lights_off[voltage] = (mean_cen, total_err)

def get_plot_arrays_on(lights_on):
    voltage = sorted(lights_on.keys())
    rate = np.array([lights_on[i][0] for i in voltage])
    err = np.array([lights_on[i][1] for i in voltage])
    mask = np.isfinite(rate) & (err > 0)
    return np.array(voltage)[mask], rate[mask], err[mask]

def get_plot_arrays_off(lights_off):
    voltage = sorted(lights_off.keys())
    rate = np.array([lights_off[i][0] for i in voltage])
    err = np.array([lights_off[i][1] for i in voltage])
    mask = np.isfinite(rate) & (err > 0)
    return np.array(voltage)[mask], rate[mask], err[mask]


def exponential_C(V, A, B, C):
    return A * np.exp(B * V) + C

def exponential(V, A, B):
    return A * np.exp(B * V)

def linear(V, m, c):
    return m*V + c

V_fit_on, Rate_fit_on, Err_fit_on = get_plot_arrays_on(lights_on)
V_fit_off, Rate_fit_off, Err_fit_off = get_plot_arrays_off(lights_off)
print(V_fit_on)
print(V_fit_off)

try:
    popt_on, pcov_on = curve_fit(
        f=exponential,
        xdata=V_fit_on,
        ydata=Rate_fit_on,
        sigma=Err_fit_on,
        absolute_sigma=False,
        p0=[1e-4, 1e-5]  # Initial guess for A, B
    )
    rate_fit_on_points = exponential(V_fit_on, *popt_on)
    perr_on = np.sqrt(np.diag(pcov_on))
except RuntimeError:
    print("Lights On curve fit failed.")
    popt_on = None

V_dense_on = np.linspace(np.min(V_fit_on), np.max(V_fit_on), 1000)
Rate_dense_on = exponential(V_dense_on, *popt_on)



'''
voltages_off_np = np.array(voltages_off)
average_rate_off_np = np.array(average_rate_off)
average_err_off_np = np.array(average_err_off)

finite_mask_off = np.isfinite(average_rate_off_np) & np.isfinite(average_err_off_np)

V_fit_off = voltages_off_np[finite_mask_off]
Rate_fit_off = average_rate_off_np[finite_mask_off]
Err_fit_off = average_err_off_np[finite_mask_off]

'''
try:
    popt_off, pcov_off = curve_fit(
        f=exponential,
        xdata=V_fit_off,
        ydata=Rate_fit_off,
        sigma=Err_fit_off,
        absolute_sigma=False,
        p0=[1e-4, 1e-6]  # Initial guess for A, B
    )
    rate_fit_off_points = exponential(V_fit_off, *popt_off)
    perr_off = np.sqrt(np.diag(pcov_off))
except RuntimeError:
    print("Lights Off curve fit failed.")
    popt_off = None

V_dense_off = np.linspace(np.min(V_fit_off), np.max(V_fit_off), 1000)
Rate_dense_off = exponential(V_dense_off, *popt_off)

fig, (ax_main, ax_res) = plt.subplots(
    nrows=2, 
    ncols=1, 
    sharex=True, 
    figsize=(7, 7), 
    gridspec_kw={'height_ratios': [3, 1], 'hspace': 0} # 3:1 ratio and no vertical space
)



# --- Residuals Calculation and Plotting ---



# 1. Calculate and Plot Lights On Residuals
if popt_on is not None:
    # Residuals = (Measured Rate) - (Fitted Rate at that Voltage)
    residuals_on = Rate_fit_on - rate_fit_on_points
    
    # Optional: Plot standardized residuals (Residuals / Error) if you want to normalize by uncertainty
    # standardized_residuals_on = residuals_on / average_err_on_np
    ax_res.errorbar(
        V_fit_on, 
        residuals_on, 
        yerr=Err_fit_on, 
        ms=3, 
        capsize=4, 
        fmt='o', 
        color='blue')#, 
        #label='Lights On Residuals'
    #)

# 2. Calculate and Plot Lights Off Residuals
if popt_off is not None:
    residuals_off = Rate_fit_off - rate_fit_off_points
    
    ax_res.errorbar(
        V_fit_off, 
        residuals_off, 
        yerr=Err_fit_off, 
        ms=3, 
        capsize=4, 
        fmt='o', 
        color='magenta')#, 
       # label='Lights Off Residuals'
    #)

# ---- Chi-squared: Lights ON ----
chi2_on = None
chi2nu_on = None

if popt_on is not None:
    non_zero = Err_fit_on > 0
    chi2_on = np.sum((residuals_on[non_zero] / Err_fit_on[non_zero])**2)
    nu_on = len(Rate_fit_on[non_zero]) - len(popt_on)
    chi2nu_on = chi2_on / nu_on


# ---- Chi-squared: Lights OFF ----
chi2_off = None
chi2nu_off = None

if popt_off is not None:
    non_zero = Err_fit_off > 0
    chi2_off = np.sum((residuals_off[non_zero] / Err_fit_off[non_zero])**2)
    nu_off = len(Rate_fit_off[non_zero]) - len(popt_off)
    chi2nu_off = chi2_off / nu_off

# corect decimal places
def fmt_sig_figs(val, n=2):
    """Rounds a number to n significant figures and returns as a string."""
    if val == 0:
        return "0"
    # Calculate the order of magnitude
    mag = floor(log10(abs(val)))
    # Round to the appropriate decimal place
    rounded_val = round(val, -int(mag - (n - 1)))
    # Format as a float to avoid scientific notation in the string
    return f"{rounded_val:g}"

def format_scientific_latex(val, err, n=2):
    """
    Formats a value and error into LaTeX scientific notation 
    sharing the same power of 10.
    """
    if err <= 0:
        return f"{val:.1e} \pm {err:.1e}"

    # 1. Find the exponent of the value
    exponent = floor(log10(abs(val)))
    
    # 2. Scale both by that exponent
    factor = 10**exponent
    scaled_val = val / factor
    scaled_err = err / factor
    
    # 3. Return the LaTeX string
    # n controls decimal places (e.g., n=2 gives 1.23)
    return (f"({scaled_val:.{n}f} \pm {scaled_err:.{n}f}) "
            f"\\times 10^{{{exponent}}}")

# ---- Lights ON fit ----
if popt_on is not None:
    a_tex_on = format_scientific_latex(popt_on[0], perr_on[0], n=2)
    b_tex_on = format_scientific_latex(popt_on[1], perr_on[1], n=2)
    
    label_on = (
        r'Lights On fit: $A e^{BV}$' +
        f'\nA = ${a_tex_on}$' +
        f'\nB = ${b_tex_on}$'
    )
    if chi2nu_on is not None:
        label_on += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_on, n=2)}'

# ---- Lights OFF fit ----
if popt_off is not None:
    a_tex_off = format_scientific_latex(popt_off[0], perr_off[0], n=2)
    b_tex_off = format_scientific_latex(popt_off[1], perr_off[1], n=2)
    
    label_off = (
        r'Lights Off fit: $A e^{BV}$' +
        f'\nA = ${a_tex_off}$' +
        f'\nB = ${b_tex_off}$'
    )
    if chi2nu_off is not None:
        label_off += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_off, n=2)}'


ax_main.errorbar(V_fit_on, Rate_fit_on, yerr = Err_fit_on, ms=4, capsize=6, fmt='o', color='blue', label = 'Lights On')
ax_main.errorbar(V_fit_off, Rate_fit_off, yerr=Err_fit_off, ms=4, capsize=6, fmt='o', color='magenta', label = 'Lights Off')
if popt_on is not None:
    ax_main.plot(V_dense_on, Rate_dense_on, 'b-', label=label_on)
# Plot the 'Lights Off' fit line, connecting the fitted points
if popt_off is not None:
    ax_main.plot(V_dense_off, Rate_dense_off, color='magenta', linestyle='-', label=label_off)
plt.xlabel('High Voltage Source (V)')
ax_main.set_ylabel('Dark Rate (Hz)')
plt.title('PMT 1 (15σ threshold) ', loc='right', fontsize='medium')
ax_main.legend(loc='upper left', fontsize='medium', frameon=False)
# Remove the x-axis tick labels for the main plot since the x-axis is shared

ax_res.axhline(0, color='gray', linestyle='--') # Draw a horizontal line at y=0
ax_main.tick_params(axis='x', labelbottom=False)
ax_res.set_xlabel('High Voltage Source (V)')
ax_res.set_ylabel('Residuals (Hz)')
ax_res.grid(True, linestyle=':', alpha=0.7)
ax_res.legend(loc='lower left', fontsize='small', frameon=False)



# 3. Final Display
plt.tight_layout(rect=[0, 0, 1, 0.96]) # Adjust layout to make room for suptitle
plt.show()
# Out:
# [1750 1800 1850 1900 1950 2000]
# [1750 1800 1850 1900 1950 2000]
# <>:218: SyntaxWarning: invalid escape sequence '\p'
# <>:230: SyntaxWarning: invalid escape sequence '\p'
# <>:244: SyntaxWarning: invalid escape sequence '\c'
# <>:257: SyntaxWarning: invalid escape sequence '\c'
# <>:218: SyntaxWarning: invalid escape sequence '\p'
# <>:230: SyntaxWarning: invalid escape sequence '\p'
# <>:244: SyntaxWarning: invalid escape sequence '\c'
# <>:257: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\holly\AppData\Local\Temp\ipykernel_22012\3032483451.py:218: SyntaxWarning: invalid escape sequence '\p'
#   return f"{val:.1e} \pm {err:.1e}"
# C:\Users\holly\AppData\Local\Temp\ipykernel_22012\3032483451.py:230: SyntaxWarning: invalid escape sequence '\p'
#   return (f"({scaled_val:.{n}f} \pm {scaled_err:.{n}f}) "
# C:\Users\holly\AppData\Local\Temp\ipykernel_22012\3032483451.py:244: SyntaxWarning: invalid escape sequence '\c'
#   label_on += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_on, n=2)}'
# C:\Users\holly\AppData\Local\Temp\ipykernel_22012\3032483451.py:257: SyntaxWarning: invalid escape sequence '\c'
#   label_off += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_off, n=2)}'
# C:\Users\holly\AppData\Local\Temp\ipykernel_22012\3032483451.py:278: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_res.legend(loc='lower left', fontsize='small', frameon=False)

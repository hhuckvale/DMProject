# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import re
from scipy.optimize import curve_fit
from math import floor, log10

# %%
"""
Cleaned CSV has columns:

            'baseline': mean_b_array,
            'sd_baseline': sigma_b_array,
            'amplitude': all_amplitudes,
            'peak_time': all_peak_times,
            'FWHM': all_FWHM,
            't1_of_FWHM': all_t1,
            't2_of_FWHM': all_t2,
            'time_above_15sigma': all_time_above_15thresh,
            'first_15sigma_crossing': all_first_15crossing,
            'second_15sigma_crossing': all_second_15crossing,
            'time_above_10sigma': all_time_above_10thresh,
            'first_10sigma_crossing': all_first_10crossing,
            'second_10sigma_crossing': all_second_10crossing,
            'time_above_5sigma': all_time_above_5thresh,
            'first_5sigma_crossing': all_first_5crossing,
            'second_5sigma_crossing': all_second_5crossing,
            'integral_pC': all_integrals_picocharge,
            'peaks_over_15sigma_threshold': number_of_maxima_all,
            'event_timestamps' : event_timestamps[:-1]
"""
# Out:
# "\nCleaned CSV has columns:\n\n            'baseline': mean_b_array,\n            'sd_baseline': sigma_b_array,\n            'amplitude': all_amplitudes,\n            'peak_time': all_peak_times,\n            'FWHM': all_FWHM,\n            't1_of_FWHM': all_t1,\n            't2_of_FWHM': all_t2,\n            'time_above_15sigma': all_time_above_15thresh,\n            'first_15sigma_crossing': all_first_15crossing,\n            'second_15sigma_crossing': all_second_15crossing,\n            'time_above_10sigma': all_time_above_10thresh,\n            'first_10sigma_crossing': all_first_10crossing,\n            'second_10sigma_crossing': all_second_10crossing,\n            'time_above_5sigma': all_time_above_5thresh,\n            'first_5sigma_crossing': all_first_5crossing,\n            'second_5sigma_crossing': all_second_5crossing,\n            'integral_pC': all_integrals_picocharge,\n            'peaks_over_15sigma_threshold': number_of_maxima_all,\n            'event_timestamps' : event_timestamps[:-1]\n"

# %%
"""
Need to find an average over three trials.
Some trials end up having very low numbers of events (super noisy data collection), these shouldn't be considered.
Need to plot dark rate against voltage. 
Try using the naming convention to loop over events and plot them? 

Name: date+note+voltage+10000+trialnumber+lights+clean.csv

"""
# Out:
# "\nNeed to find an average over three trials.\nSome trials end up having very low numbers of events (super noisy data collection), these shouldn't be considered.\nNeed to plot dark rate against voltage. \nTry using the naming convention to loop over events and plot them? \n\nName: date+note+voltage+10000+trialnumber+lights+clean.csv\n\n"

# %%
#15sigma threshold

#eliminate files with less than 1000 events in after cleaning.

allfiles = glob.glob('PMT7_Cleaned/*cleaned.csv')

enough_events = []

for f in allfiles:
    df = pd.read_csv(f)
    if len(df)<500:
        print(f"Discarding {f}, only {len(df)} events after cleaning")
        continue
    enough_events.append(f)
# Out:
# Discarding PMT7_Cleaned\020226_darkrate_2000_10000_1_off_processed_threshold26_cleaned.csv, only 23 events after cleaning
# Discarding PMT7_Cleaned\020226_darkrate_2000_10000_1_off_processed_threshold27_cleaned.csv, only 23 events after cleaning
# Discarding PMT7_Cleaned\020226_darkrate_2000_10000_1_off_processed_threshold28_cleaned.csv, only 23 events after cleaning

# %%
#15sigma threshold

# first find the place value of the smallest digit in the timesteps:
def last_digit_place_value(x):
    """
    Returns the place value of the last digit in x.
    Example: 0.1234 -> 0.0001, 15.20 -> 0.01, 5000 -> 1000
    """
    s = str(x)

    # Handle scientific notation
    if 'e' in s.lower():
        s = format(float(x), '.15f').rstrip('0').rstrip('.')

    if '.' in s:
        frac_part = s.split('.')[1]
        return 10 ** (-len(frac_part))
    else:
        trailing_zeros = len(s) - len(s.rstrip('0'))
        return 10 ** trailing_zeros
    
#calculate dark rate for each csv in enough_events and their errors
dark_rates = {}
raw_storage = {}
for file in enough_events:
    df = pd.read_csv(file)
    timestamp_column = df['event_timestamps']
    timetaken = timestamp_column.iloc[-1] - timestamp_column.iloc[0]
    amplitude_column = df['amplitude']
    dark_rate = len(amplitude_column) / timetaken

    if dark_rate > 3000: 
        print(f"Discarding {file} due to unusual dark rate = {dark_rate:.3f}Hz")
        continue
# calculate errors
    N = len(amplitude_column)
    t_last_err = 0.5 * last_digit_place_value(timestamp_column.iloc[-1])
    t_first_err = 0.5 * last_digit_place_value(timestamp_column.iloc[0])
    t_err = np.sqrt(t_last_err**2 + t_first_err**2)
    DR_err = np.sqrt((np.sqrt(N)/timetaken)**2 + ((N*t_err)/timetaken**2)**2)
    
    print(DR_err)

    match = re.search(r"darkrate_(\d+)_10000_(\d+)_(on|off)_processed_threshold(\d+).*", file)
    if not match:
        continue
    
    voltage = int(match.group(1))
    light_state = match.group(3)
    thresh = int(match.group(4)) # e.g., 11

    raw_storage.setdefault(thresh, {}).setdefault(voltage, {}).setdefault(light_state, []).append((dark_rate, DR_err))


    dark_rates[file] = (dark_rate, DR_err)
    print(f"{file} has dark rate = {dark_rate:.3f} Hz")
    print(f"{file} ",'amount of events in clean files', len(amplitude_column))

#PUT ERROR PROPAGATION HERE FOR EACH RATE
# Out:
# 4.661022922162811
# PMT7_Cleaned\020226_darkrate_1800_10000_1_off_processed_threshold26_cleaned.csv has dark rate = 453.247 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_1_off_processed_threshold26_cleaned.csv  amount of events in clean files 9456
# 4.642996594483946
# PMT7_Cleaned\020226_darkrate_1800_10000_1_off_processed_threshold27_cleaned.csv has dark rate = 449.748 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_1_off_processed_threshold27_cleaned.csv  amount of events in clean files 9383
# 4.610222091160936
# PMT7_Cleaned\020226_darkrate_1800_10000_1_off_processed_threshold28_cleaned.csv has dark rate = 443.421 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_1_off_processed_threshold28_cleaned.csv  amount of events in clean files 9251
# 4.431706077745608
# PMT7_Cleaned\020226_darkrate_1800_10000_1_on_processed_threshold26_cleaned.csv has dark rate = 431.449 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_1_on_processed_threshold26_cleaned.csv  amount of events in clean files 9478
# 4.424686846143234
# PMT7_Cleaned\020226_darkrate_1800_10000_1_on_processed_threshold27_cleaned.csv has dark rate = 430.083 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_1_on_processed_threshold27_cleaned.csv  amount of events in clean files 9448
# 4.4110846600865035
# PMT7_Cleaned\020226_darkrate_1800_10000_1_on_processed_threshold28_cleaned.csv has dark rate = 427.443 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_1_on_processed_threshold28_cleaned.csv  amount of events in clean files 9390
# 4.596299503226493
# PMT7_Cleaned\020226_darkrate_1800_10000_2_off_processed_threshold26_cleaned.csv has dark rate = 438.411 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_2_off_processed_threshold26_cleaned.csv  amount of events in clean files 9098
# 4.563644919657866
# PMT7_Cleaned\020226_darkrate_1800_10000_2_off_processed_threshold27_cleaned.csv has dark rate = 432.151 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_2_off_processed_threshold27_cleaned.csv  amount of events in clean files 8967
# 4.501642259622626
# PMT7_Cleaned\020226_darkrate_1800_10000_2_off_processed_threshold28_cleaned.csv has dark rate = 420.488 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_2_off_processed_threshold28_cleaned.csv  amount of events in clean files 8725
# 4.756359442758318
# PMT7_Cleaned\020226_darkrate_1800_10000_2_on_processed_threshold26_cleaned.csv has dark rate = 463.812 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_2_on_processed_threshold26_cleaned.csv  amount of events in clean files 9509
# 4.746846213653162
# PMT7_Cleaned\020226_darkrate_1800_10000_2_on_processed_threshold27_cleaned.csv has dark rate = 461.959 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_2_on_processed_threshold27_cleaned.csv  amount of events in clean files 9471
# 4.731032134563319
# PMT7_Cleaned\020226_darkrate_1800_10000_2_on_processed_threshold28_cleaned.csv has dark rate = 458.886 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_2_on_processed_threshold28_cleaned.csv  amount of events in clean files 9408
# 4.795265180603907
# PMT7_Cleaned\020226_darkrate_1800_10000_3_off_processed_threshold26_cleaned.csv has dark rate = 464.324 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_3_off_processed_threshold26_cleaned.csv  amount of events in clean files 9376
# 4.746048045352299
# PMT7_Cleaned\020226_darkrate_1800_10000_3_off_processed_threshold27_cleaned.csv has dark rate = 454.804 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_3_off_processed_threshold27_cleaned.csv  amount of events in clean files 9183
# 4.669981319435717
# PMT7_Cleaned\020226_darkrate_1800_10000_3_off_processed_threshold28_cleaned.csv has dark rate = 440.342 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_3_off_processed_threshold28_cleaned.csv  amount of events in clean files 8891
# 4.650928219290238
# PMT7_Cleaned\020226_darkrate_1800_10000_3_on_processed_threshold26_cleaned.csv has dark rate = 451.523 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_3_on_processed_threshold26_cleaned.csv  amount of events in clean files 9425
# 4.637090552861128
# PMT7_Cleaned\020226_darkrate_1800_10000_3_on_processed_threshold27_cleaned.csv has dark rate = 448.841 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_3_on_processed_threshold27_cleaned.csv  amount of events in clean files 9369
# 4.609290594475608
# PMT7_Cleaned\020226_darkrate_1800_10000_3_on_processed_threshold28_cleaned.csv has dark rate = 443.475 Hz
# PMT7_Cleaned\020226_darkrate_1800_10000_3_on_processed_threshold28_cleaned.csv  amount of events in clean files 9257
# 10.140715763144968
# PMT7_Cleaned\020226_darkrate_1850_10000_1_off_processed_threshold26_cleaned.csv has dark rate = 1001.315 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_1_off_processed_threshold26_cleaned.csv  amount of events in clean files 9750
# 10.120414009521555
# PMT7_Cleaned\020226_darkrate_1850_10000_1_off_processed_threshold27_cleaned.csv has dark rate = 997.310 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_1_off_processed_threshold27_cleaned.csv  amount of events in clean files 9711
# 10.077594873738759
# PMT7_Cleaned\020226_darkrate_1850_10000_1_off_processed_threshold28_cleaned.csv has dark rate = 988.889 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_1_off_processed_threshold28_cleaned.csv  amount of events in clean files 9629
# 10.840745694621116
# PMT7_Cleaned\020226_darkrate_1850_10000_1_on_processed_threshold26_cleaned.csv has dark rate = 1069.724 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_1_on_processed_threshold26_cleaned.csv  amount of events in clean files 9737
# 10.813992142610193
# PMT7_Cleaned\020226_darkrate_1850_10000_1_on_processed_threshold27_cleaned.csv has dark rate = 1064.451 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_1_on_processed_threshold27_cleaned.csv  amount of events in clean files 9689
# 10.761051377716232
# PMT7_Cleaned\020226_darkrate_1850_10000_1_on_processed_threshold28_cleaned.csv has dark rate = 1053.594 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_1_on_processed_threshold28_cleaned.csv  amount of events in clean files 9586
# 10.161529088295497
# PMT7_Cleaned\020226_darkrate_1850_10000_2_off_processed_threshold26_cleaned.csv has dark rate = 1002.032 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_2_off_processed_threshold26_cleaned.csv  amount of events in clean files 9724
# 10.134322803628539
# PMT7_Cleaned\020226_darkrate_1850_10000_2_off_processed_threshold27_cleaned.csv has dark rate = 996.673 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_2_off_processed_threshold27_cleaned.csv  amount of events in clean files 9672
# 10.084955958596613
# PMT7_Cleaned\020226_darkrate_1850_10000_2_off_processed_threshold28_cleaned.csv has dark rate = 986.987 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_2_off_processed_threshold28_cleaned.csv  amount of events in clean files 9578
# 10.549279126795806
# PMT7_Cleaned\020226_darkrate_1850_10000_2_on_processed_threshold26_cleaned.csv has dark rate = 1041.872 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_2_on_processed_threshold26_cleaned.csv  amount of events in clean files 9754
# 10.519494906170452
# PMT7_Cleaned\020226_darkrate_1850_10000_2_on_processed_threshold27_cleaned.csv has dark rate = 1035.997 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_2_on_processed_threshold27_cleaned.csv  amount of events in clean files 9699
# 10.470029496501523
# PMT7_Cleaned\020226_darkrate_1850_10000_2_on_processed_threshold28_cleaned.csv has dark rate = 1026.277 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_2_on_processed_threshold28_cleaned.csv  amount of events in clean files 9608
# 12.80491334680185
# PMT7_Cleaned\020226_darkrate_1850_10000_3_off_processed_threshold26_cleaned.csv has dark rate = 1262.697 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_3_off_processed_threshold26_cleaned.csv  amount of events in clean files 9724
# 12.786464352260799
# PMT7_Cleaned\020226_darkrate_1850_10000_3_off_processed_threshold27_cleaned.csv has dark rate = 1259.061 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_3_off_processed_threshold27_cleaned.csv  amount of events in clean files 9696
# 12.758740841103178
# PMT7_Cleaned\020226_darkrate_1850_10000_3_off_processed_threshold28_cleaned.csv has dark rate = 1253.607 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_3_off_processed_threshold28_cleaned.csv  amount of events in clean files 9654
# 10.502487421193305
# PMT7_Cleaned\020226_darkrate_1850_10000_3_on_processed_threshold26_cleaned.csv has dark rate = 1036.133 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_3_on_processed_threshold26_cleaned.csv  amount of events in clean files 9733
# 10.487909999420124
# PMT7_Cleaned\020226_darkrate_1850_10000_3_on_processed_threshold27_cleaned.csv has dark rate = 1033.259 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_3_on_processed_threshold27_cleaned.csv  amount of events in clean files 9706
# 10.463569166173254
# PMT7_Cleaned\020226_darkrate_1850_10000_3_on_processed_threshold28_cleaned.csv has dark rate = 1028.468 Hz
# PMT7_Cleaned\020226_darkrate_1850_10000_3_on_processed_threshold28_cleaned.csv  amount of events in clean files 9661
# 12.77431433802231
# PMT7_Cleaned\020226_darkrate_1900_10000_1_on_processed_threshold26_cleaned.csv has dark rate = 1256.956 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_1_on_processed_threshold26_cleaned.csv  amount of events in clean files 9682
# 12.742609682713137
# PMT7_Cleaned\020226_darkrate_1900_10000_1_on_processed_threshold27_cleaned.csv has dark rate = 1250.725 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_1_on_processed_threshold27_cleaned.csv  amount of events in clean files 9634
# 12.702867586698302
# PMT7_Cleaned\020226_darkrate_1900_10000_1_on_processed_threshold28_cleaned.csv has dark rate = 1242.935 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_1_on_processed_threshold28_cleaned.csv  amount of events in clean files 9574
# 11.397982134479719
# PMT7_Cleaned\020226_darkrate_1900_10000_2_off_processed_threshold26_cleaned.csv has dark rate = 1109.534 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_2_off_processed_threshold26_cleaned.csv  amount of events in clean files 9476
# 11.347955055164592
# PMT7_Cleaned\020226_darkrate_1900_10000_2_off_processed_threshold27_cleaned.csv has dark rate = 1099.815 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_2_off_processed_threshold27_cleaned.csv  amount of events in clean files 9393
# 11.292851401998085
# PMT7_Cleaned\020226_darkrate_1900_10000_2_off_processed_threshold28_cleaned.csv has dark rate = 1089.160 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_2_off_processed_threshold28_cleaned.csv  amount of events in clean files 9302
# 11.753853463762805
# PMT7_Cleaned\020226_darkrate_1900_10000_2_on_processed_threshold26_cleaned.csv has dark rate = 1151.698 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_2_on_processed_threshold26_cleaned.csv  amount of events in clean files 9601
# 11.729956643261282
# PMT7_Cleaned\020226_darkrate_1900_10000_2_on_processed_threshold27_cleaned.csv has dark rate = 1147.019 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_2_on_processed_threshold27_cleaned.csv  amount of events in clean files 9562
# 11.693096941851161
# PMT7_Cleaned\020226_darkrate_1900_10000_2_on_processed_threshold28_cleaned.csv has dark rate = 1139.822 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_2_on_processed_threshold28_cleaned.csv  amount of events in clean files 9502
# 11.554366825771039
# PMT7_Cleaned\020226_darkrate_1900_10000_3_off_processed_threshold26_cleaned.csv has dark rate = 1136.271 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_3_off_processed_threshold26_cleaned.csv  amount of events in clean files 9671
# 11.517869498412427
# PMT7_Cleaned\020226_darkrate_1900_10000_3_off_processed_threshold27_cleaned.csv has dark rate = 1129.104 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_3_off_processed_threshold27_cleaned.csv  amount of events in clean files 9610
# 11.466818854358122
# PMT7_Cleaned\020226_darkrate_1900_10000_3_off_processed_threshold28_cleaned.csv has dark rate = 1119.117 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_3_off_processed_threshold28_cleaned.csv  amount of events in clean files 9525
# 11.523672278535331
# PMT7_Cleaned\020226_darkrate_1900_10000_3_on_processed_threshold26_cleaned.csv has dark rate = 1115.537 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_3_on_processed_threshold26_cleaned.csv  amount of events in clean files 9371
# 11.487955151412443
# PMT7_Cleaned\020226_darkrate_1900_10000_3_on_processed_threshold27_cleaned.csv has dark rate = 1108.632 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_3_on_processed_threshold27_cleaned.csv  amount of events in clean files 9313
# 11.442842374548343
# PMT7_Cleaned\020226_darkrate_1900_10000_3_on_processed_threshold28_cleaned.csv has dark rate = 1099.942 Hz
# PMT7_Cleaned\020226_darkrate_1900_10000_3_on_processed_threshold28_cleaned.csv  amount of events in clean files 9240
# 14.138048424241989
# PMT7_Cleaned\020226_darkrate_1950_10000_1_off_processed_threshold26_cleaned.csv has dark rate = 1381.917 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_1_off_processed_threshold26_cleaned.csv  amount of events in clean files 9554
# 14.123983288940329
# PMT7_Cleaned\020226_darkrate_1950_10000_1_off_processed_threshold27_cleaned.csv has dark rate = 1379.169 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_1_off_processed_threshold27_cleaned.csv  amount of events in clean files 9535
# 14.098037096442942
# PMT7_Cleaned\020226_darkrate_1950_10000_1_off_processed_threshold28_cleaned.csv has dark rate = 1374.107 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_1_off_processed_threshold28_cleaned.csv  amount of events in clean files 9500
# 13.80144781934096
# PMT7_Cleaned\020226_darkrate_1950_10000_1_on_processed_threshold26_cleaned.csv has dark rate = 1350.921 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_1_on_processed_threshold26_cleaned.csv  amount of events in clean files 9581
# 13.788477208176744
# PMT7_Cleaned\020226_darkrate_1950_10000_1_on_processed_threshold27_cleaned.csv has dark rate = 1348.383 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_1_on_processed_threshold27_cleaned.csv  amount of events in clean files 9563
# 13.769720311123576
# PMT7_Cleaned\020226_darkrate_1950_10000_1_on_processed_threshold28_cleaned.csv has dark rate = 1344.717 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_1_on_processed_threshold28_cleaned.csv  amount of events in clean files 9537
# 13.995290648671524
# PMT7_Cleaned\020226_darkrate_1950_10000_2_off_processed_threshold26_cleaned.csv has dark rate = 1373.394 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_2_off_processed_threshold26_cleaned.csv  amount of events in clean files 9630
# 13.959639360389481
# PMT7_Cleaned\020226_darkrate_1950_10000_2_off_processed_threshold27_cleaned.csv has dark rate = 1366.406 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_2_off_processed_threshold27_cleaned.csv  amount of events in clean files 9581
# 13.914398655949592
# PMT7_Cleaned\020226_darkrate_1950_10000_2_off_processed_threshold28_cleaned.csv has dark rate = 1357.563 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_2_off_processed_threshold28_cleaned.csv  amount of events in clean files 9519
# 13.755444281637928
# PMT7_Cleaned\020226_darkrate_1950_10000_2_on_processed_threshold26_cleaned.csv has dark rate = 1350.558 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_2_on_processed_threshold26_cleaned.csv  amount of events in clean files 9640
# 13.736167444740707
# PMT7_Cleaned\020226_darkrate_1950_10000_2_on_processed_threshold27_cleaned.csv has dark rate = 1346.775 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_2_on_processed_threshold27_cleaned.csv  amount of events in clean files 9613
# 13.723301176943313
# PMT7_Cleaned\020226_darkrate_1950_10000_2_on_processed_threshold28_cleaned.csv has dark rate = 1344.253 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_2_on_processed_threshold28_cleaned.csv  amount of events in clean files 9595
# 14.045326114814353
# PMT7_Cleaned\020226_darkrate_1950_10000_3_off_processed_threshold26_cleaned.csv has dark rate = 1380.592 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_3_off_processed_threshold26_cleaned.csv  amount of events in clean files 9662
# 14.029326670148935
# PMT7_Cleaned\020226_darkrate_1950_10000_3_off_processed_threshold27_cleaned.csv has dark rate = 1377.448 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_3_off_processed_threshold27_cleaned.csv  amount of events in clean files 9640
# 14.010394679719811
# PMT7_Cleaned\020226_darkrate_1950_10000_3_off_processed_threshold28_cleaned.csv has dark rate = 1373.733 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_3_off_processed_threshold28_cleaned.csv  amount of events in clean files 9614
# 14.113443212909491
# PMT7_Cleaned\020226_darkrate_1950_10000_3_on_processed_threshold26_cleaned.csv has dark rate = 1386.785 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_3_on_processed_threshold26_cleaned.csv  amount of events in clean files 9655
# 14.095890991529995
# PMT7_Cleaned\020226_darkrate_1950_10000_3_on_processed_threshold27_cleaned.csv has dark rate = 1383.338 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_3_on_processed_threshold27_cleaned.csv  amount of events in clean files 9631
# 14.07098786510576
# PMT7_Cleaned\020226_darkrate_1950_10000_3_on_processed_threshold28_cleaned.csv has dark rate = 1378.454 Hz
# PMT7_Cleaned\020226_darkrate_1950_10000_3_on_processed_threshold28_cleaned.csv  amount of events in clean files 9597
# 20.715239359772063
# PMT7_Cleaned\020226_darkrate_2000_10000_1_on_processed_threshold26_cleaned.csv has dark rate = 1675.375 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_1_on_processed_threshold26_cleaned.csv  amount of events in clean files 6541
# 20.70415195021389
# PMT7_Cleaned\020226_darkrate_2000_10000_1_on_processed_threshold27_cleaned.csv has dark rate = 1673.582 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_1_on_processed_threshold27_cleaned.csv  amount of events in clean files 6534
# 20.68671687179507
# PMT7_Cleaned\020226_darkrate_2000_10000_1_on_processed_threshold28_cleaned.csv has dark rate = 1670.765 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_1_on_processed_threshold28_cleaned.csv  amount of events in clean files 6523
# 17.0241873938327
# PMT7_Cleaned\020226_darkrate_2000_10000_2_off_processed_threshold26_cleaned.csv has dark rate = 1613.710 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_2_off_processed_threshold26_cleaned.csv  amount of events in clean files 8985
# 17.005229495531356
# PMT7_Cleaned\020226_darkrate_2000_10000_2_off_processed_threshold27_cleaned.csv has dark rate = 1610.118 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_2_off_processed_threshold27_cleaned.csv  amount of events in clean files 8965
# 16.976752953928656
# PMT7_Cleaned\020226_darkrate_2000_10000_2_off_processed_threshold28_cleaned.csv has dark rate = 1604.730 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_2_off_processed_threshold28_cleaned.csv  amount of events in clean files 8935
# 17.168806527839102
# PMT7_Cleaned\020226_darkrate_2000_10000_2_on_processed_threshold26_cleaned.csv has dark rate = 1668.115 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_2_on_processed_threshold26_cleaned.csv  amount of events in clean files 9440
# 17.156070697579686
# PMT7_Cleaned\020226_darkrate_2000_10000_2_on_processed_threshold27_cleaned.csv has dark rate = 1665.642 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_2_on_processed_threshold27_cleaned.csv  amount of events in clean files 9426
# 17.146967884449406
# PMT7_Cleaned\020226_darkrate_2000_10000_2_on_processed_threshold28_cleaned.csv has dark rate = 1663.874 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_2_on_processed_threshold28_cleaned.csv  amount of events in clean files 9416
# 17.411925932882735
# PMT7_Cleaned\020226_darkrate_2000_10000_3_off_processed_threshold26_cleaned.csv has dark rate = 1700.139 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_3_off_processed_threshold26_cleaned.csv  amount of events in clean files 9534
# 17.402792046751966
# PMT7_Cleaned\020226_darkrate_2000_10000_3_off_processed_threshold27_cleaned.csv has dark rate = 1698.356 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_3_off_processed_threshold27_cleaned.csv  amount of events in clean files 9524
# 17.38542444262038
# PMT7_Cleaned\020226_darkrate_2000_10000_3_off_processed_threshold28_cleaned.csv has dark rate = 1694.967 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_3_off_processed_threshold28_cleaned.csv  amount of events in clean files 9505
# 17.12913244302446
# PMT7_Cleaned\020226_darkrate_2000_10000_3_on_processed_threshold26_cleaned.csv has dark rate = 1674.017 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_3_on_processed_threshold26_cleaned.csv  amount of events in clean files 9551
# 17.1129838832088
# PMT7_Cleaned\020226_darkrate_2000_10000_3_on_processed_threshold27_cleaned.csv has dark rate = 1670.862 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_3_on_processed_threshold27_cleaned.csv  amount of events in clean files 9533
# 17.086035700169
# PMT7_Cleaned\020226_darkrate_2000_10000_3_on_processed_threshold28_cleaned.csv has dark rate = 1665.604 Hz
# PMT7_Cleaned\020226_darkrate_2000_10000_3_on_processed_threshold28_cleaned.csv  amount of events in clean files 9503
# 0.9050655498324857
# PMT7_Cleaned\300126_darkrate_1750_10000_1_off_processed_threshold26_cleaned.csv has dark rate = 86.797 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_1_off_processed_threshold26_cleaned.csv  amount of events in clean files 9197
# 0.9013182586369151
# PMT7_Cleaned\300126_darkrate_1750_10000_1_off_processed_threshold27_cleaned.csv has dark rate = 86.079 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_1_off_processed_threshold27_cleaned.csv  amount of events in clean files 9121
# 0.8943244609381092
# PMT7_Cleaned\300126_darkrate_1750_10000_1_off_processed_threshold28_cleaned.csv has dark rate = 84.749 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_1_off_processed_threshold28_cleaned.csv  amount of events in clean files 8980
# 0.7961315437812883
# PMT7_Cleaned\300126_darkrate_1750_10000_1_on_processed_threshold26_cleaned.csv has dark rate = 77.060 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_1_on_processed_threshold26_cleaned.csv  amount of events in clean files 9369
# 0.7950686457294587
# PMT7_Cleaned\300126_darkrate_1750_10000_1_on_processed_threshold27_cleaned.csv has dark rate = 76.855 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_1_on_processed_threshold27_cleaned.csv  amount of events in clean files 9344
# 0.7936208198826645
# PMT7_Cleaned\300126_darkrate_1750_10000_1_on_processed_threshold28_cleaned.csv has dark rate = 76.575 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_1_on_processed_threshold28_cleaned.csv  amount of events in clean files 9310
# 0.9246502405772292
# PMT7_Cleaned\300126_darkrate_1750_10000_2_off_processed_threshold26_cleaned.csv has dark rate = 89.093 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_2_off_processed_threshold26_cleaned.csv  amount of events in clean files 9284
# 0.9187552791739036
# PMT7_Cleaned\300126_darkrate_1750_10000_2_off_processed_threshold27_cleaned.csv has dark rate = 87.961 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_2_off_processed_threshold27_cleaned.csv  amount of events in clean files 9166
# 0.9091324295991031
# PMT7_Cleaned\300126_darkrate_1750_10000_2_off_processed_threshold28_cleaned.csv has dark rate = 86.128 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_2_off_processed_threshold28_cleaned.csv  amount of events in clean files 8975
# 0.8588326700608255
# PMT7_Cleaned\300126_darkrate_1750_10000_2_on_processed_threshold26_cleaned.csv has dark rate = 83.227 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_2_on_processed_threshold26_cleaned.csv  amount of events in clean files 9391
# 0.8570933066881448
# PMT7_Cleaned\300126_darkrate_1750_10000_2_on_processed_threshold27_cleaned.csv has dark rate = 82.890 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_2_on_processed_threshold27_cleaned.csv  amount of events in clean files 9353
# 0.853649952487018
# PMT7_Cleaned\300126_darkrate_1750_10000_2_on_processed_threshold28_cleaned.csv has dark rate = 82.226 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_2_on_processed_threshold28_cleaned.csv  amount of events in clean files 9278
# 0.9736585516175845
# PMT7_Cleaned\300126_darkrate_1750_10000_3_off_processed_threshold26_cleaned.csv has dark rate = 93.846 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_3_off_processed_threshold26_cleaned.csv  amount of events in clean files 9290
# 0.9640739245110903
# PMT7_Cleaned\300126_darkrate_1750_10000_3_off_processed_threshold27_cleaned.csv has dark rate = 92.007 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_3_off_processed_threshold27_cleaned.csv  amount of events in clean files 9108
# 0.9504286694699863
# PMT7_Cleaned\300126_darkrate_1750_10000_3_off_processed_threshold28_cleaned.csv has dark rate = 89.421 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_3_off_processed_threshold28_cleaned.csv  amount of events in clean files 8852
# 0.8769100870206216
# PMT7_Cleaned\300126_darkrate_1750_10000_3_on_processed_threshold26_cleaned.csv has dark rate = 83.840 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_3_on_processed_threshold26_cleaned.csv  amount of events in clean files 9141
# 0.8740755257002154
# PMT7_Cleaned\300126_darkrate_1750_10000_3_on_processed_threshold27_cleaned.csv has dark rate = 83.299 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_3_on_processed_threshold27_cleaned.csv  amount of events in clean files 9082
# 0.8699272491429467
# PMT7_Cleaned\300126_darkrate_1750_10000_3_on_processed_threshold28_cleaned.csv has dark rate = 82.510 Hz
# PMT7_Cleaned\300126_darkrate_1750_10000_3_on_processed_threshold28_cleaned.csv  amount of events in clean files 8996

# %%
#15sigma threshold
#plot dark rate against voltage for lights on and lights off on the same plot.

#these will be lists of voltages with their corresponding dark rates. eg. {1750: [213,453,241], 2000: [542,622,315]}
lights_on = {} 
lights_off = {}

central_t = 27
low_t = 26
high_t = 28

def get_simple_mean(thresh, volt, state):
    data = raw_storage.get(thresh, {}).get(volt, {}).get(state, [])
    if not data: return None, None
    
    rates, errs = zip(*data)
    rates, errs = np.array(rates), np.array(errs)
    mean = np.mean(rates)
    error = np.sqrt(np.sum(errs**2)) / len(errs)
    return mean, error

# Process all voltages found in the central threshold
all_voltages = []
all_voltages = sorted(raw_storage.get(central_t, {}).keys())

for voltage in all_voltages:
    for state in ['on', 'off']:
        # Get Weighted Mean and Stat Error for Threshold 11 (central voltage)
        mean_cen, err_cen = get_simple_mean(central_t, voltage, state)
        if mean_cen is None: continue
        
        # Get Weighted Means for Threshold 10 and 12
        mean_low, _ = get_simple_mean(low_t, voltage, state)
        mean_high, _ = get_simple_mean(high_t, voltage, state)
        
        # 3. Calculate Systematic Error: |Rate_high - Rate_low| / 2
        if mean_low is not None and mean_high is not None:
            sys_err = abs(mean_high - mean_low) / 2
            print(sys_err)
        else:
            sys_err = 0.0 # Default if bounds are missing

        # 4. Combine Stat and Sys Error in Quadrature
        total_err = np.sqrt(err_cen**2 + sys_err**2)
        print(total_err)
        
        # Store in your original lights_on / lights_off dictionaries
        if state == 'on':
            lights_on[voltage] = (mean_cen, total_err)
        else:
            lights_off[voltage] = (mean_cen, total_err)

def get_plot_arrays_on(lights_on):
    voltage = sorted(lights_on.keys())
    rate = np.array([lights_on[i][0] for i in voltage])
    err = np.array([lights_on[i][1] for i in voltage])
    mask = np.isfinite(rate) & (err > 0)
    return np.array(voltage)[mask], rate[mask], err[mask]

def get_plot_arrays_off(lights_off):
    voltage = sorted(lights_off.keys())
    rate = np.array([lights_off[i][0] for i in voltage])
    err = np.array([lights_off[i][1] for i in voltage])
    mask = np.isfinite(rate) & (err > 0)
    return np.array(voltage)[mask], rate[mask], err[mask]


def exponential_C(V, A, B, C):
    return A * np.exp(B * V) + C

def exponential(V, A, B):
    return A * np.exp(B * V)

def linear(V, m, c):
    return m*V + c

V_fit_on, Rate_fit_on, Err_fit_on = get_plot_arrays_on(lights_on)
V_fit_off, Rate_fit_off, Err_fit_off = get_plot_arrays_off(lights_off)
print(V_fit_on)
print(V_fit_off)

try:
    popt_on, pcov_on = curve_fit(
        f=exponential,
        xdata=V_fit_on,
        ydata=Rate_fit_on,
        sigma=Err_fit_on,
        absolute_sigma=False,
        p0=[1e-6, 0.01]  # Initial guess for A, B
    )
    rate_fit_on_points = exponential(V_fit_on, *popt_on)
    perr_on = np.sqrt(np.diag(pcov_on))
except RuntimeError:
    print("Lights On curve fit failed.")
    popt_on = None

V_dense_on = np.linspace(np.min(V_fit_on), np.max(V_fit_on), 1000)
Rate_dense_on = exponential(V_dense_on, *popt_on)



'''
voltages_off_np = np.array(voltages_off)
average_rate_off_np = np.array(average_rate_off)
average_err_off_np = np.array(average_err_off)

finite_mask_off = np.isfinite(average_rate_off_np) & np.isfinite(average_err_off_np)

V_fit_off = voltages_off_np[finite_mask_off]
Rate_fit_off = average_rate_off_np[finite_mask_off]
Err_fit_off = average_err_off_np[finite_mask_off]

'''
try:
    popt_off, pcov_off = curve_fit(
        f=exponential,
        xdata=V_fit_off,
        ydata=Rate_fit_off,
        sigma=Err_fit_off,
        absolute_sigma=False,
        p0=[1e-6, 0.01]  # Initial guess for A, B
    )
    rate_fit_off_points = exponential(V_fit_off, *popt_off)
    perr_off = np.sqrt(np.diag(pcov_off))
except RuntimeError:
    print("Lights Off curve fit failed.")
    popt_off = None

V_dense_off = np.linspace(np.min(V_fit_off), np.max(V_fit_off), 1000)
Rate_dense_off = exponential(V_dense_off, *popt_off)

fig, (ax_main, ax_res) = plt.subplots(
    nrows=2, 
    ncols=1, 
    sharex=True, 
    figsize=(7, 7), 
    gridspec_kw={'height_ratios': [3, 1], 'hspace': 0} # 3:1 ratio and no vertical space
)



# --- Residuals Calculation and Plotting ---



# 1. Calculate and Plot Lights On Residuals
if popt_on is not None:
    # Residuals = (Measured Rate) - (Fitted Rate at that Voltage)
    residuals_on = Rate_fit_on - rate_fit_on_points
    
    # Optional: Plot standardized residuals (Residuals / Error) if you want to normalize by uncertainty
    # standardized_residuals_on = residuals_on / average_err_on_np
    ax_res.errorbar(
        V_fit_on, 
        residuals_on, 
        yerr=Err_fit_on, 
        ms=3, 
        capsize=4, 
        fmt='o', 
        color='blue')#, 
        #label='Lights On Residuals'
    #)

# 2. Calculate and Plot Lights Off Residuals
if popt_off is not None:
    residuals_off = Rate_fit_off - rate_fit_off_points
    
    ax_res.errorbar(
        V_fit_off, 
        residuals_off, 
        yerr=Err_fit_off, 
        ms=3, 
        capsize=4, 
        fmt='o', 
        color='magenta')#, 
       # label='Lights Off Residuals'
    #)

# ---- Chi-squared: Lights ON ----
chi2_on = None
chi2nu_on = None

if popt_on is not None:
    non_zero = Err_fit_on > 0
    chi2_on = np.sum((residuals_on[non_zero] / Err_fit_on[non_zero])**2)
    nu_on = len(Rate_fit_on[non_zero]) - len(popt_on)
    chi2nu_on = chi2_on / nu_on


# ---- Chi-squared: Lights OFF ----
chi2_off = None
chi2nu_off = None

if popt_off is not None:
    non_zero = Err_fit_off > 0
    chi2_off = np.sum((residuals_off[non_zero] / Err_fit_off[non_zero])**2)
    nu_off = len(Rate_fit_off[non_zero]) - len(popt_off)
    chi2nu_off = chi2_off / nu_off

# corect decimal places
def fmt_sig_figs(val, n=2):
    """Rounds a number to n significant figures and returns as a string."""
    if val == 0:
        return "0"
    # Calculate the order of magnitude
    mag = floor(log10(abs(val)))
    # Round to the appropriate decimal place
    rounded_val = round(val, -int(mag - (n - 1)))
    # Format as a float to avoid scientific notation in the string
    return f"{rounded_val:g}"

def format_scientific_latex(val, err, n=2):
    """
    Formats a value and error into LaTeX scientific notation 
    sharing the same power of 10.
    """
    if err <= 0:
        return f"{val:.1e} \pm {err:.1e}"

    # 1. Find the exponent of the value
    exponent = floor(log10(abs(val)))
    
    # 2. Scale both by that exponent
    factor = 10**exponent
    scaled_val = val / factor
    scaled_err = err / factor
    
    # 3. Return the LaTeX string
    # n controls decimal places (e.g., n=2 gives 1.23)
    return (f"({scaled_val:.{n}f} \pm {scaled_err:.{n}f}) "
            f"\\times 10^{{{exponent}}}")

# ---- Lights ON fit ----
if popt_on is not None:
    a_tex_on = format_scientific_latex(popt_on[0], perr_on[0], n=2)
    b_tex_on = format_scientific_latex(popt_on[1], perr_on[1], n=2)
    
    label_on = (
        r'Lights On fit: $A e^{BV}$' +
        f'\nA = ${a_tex_on}$' +
        f'\nB = ${b_tex_on}$'
    )
    if chi2nu_on is not None:
        label_on += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_on, n=2)}'

# ---- Lights OFF fit ----
if popt_off is not None:
    a_tex_off = format_scientific_latex(popt_off[0], perr_off[0], n=2)
    b_tex_off = format_scientific_latex(popt_off[1], perr_off[1], n=2)
    
    label_off = (
        r'Lights Off fit: $A e^{BV}$' +
        f'\nA = ${a_tex_off}$' +
        f'\nB = ${b_tex_off}$'
    )
    if chi2nu_off is not None:
        label_off += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_off, n=2)}'


ax_main.errorbar(V_fit_on, Rate_fit_on, yerr = Err_fit_on, ms=4, capsize=6, fmt='o', color='blue', label = 'Lights On')
ax_main.errorbar(V_fit_off, Rate_fit_off, yerr=Err_fit_off, ms=4, capsize=6, fmt='o', color='magenta', label = 'Lights Off')
if popt_on is not None:
    ax_main.plot(V_dense_on, Rate_dense_on, 'b-', label=label_on)
# Plot the 'Lights Off' fit line, connecting the fitted points
if popt_off is not None:
    ax_main.plot(V_dense_off, Rate_dense_off, color='magenta', linestyle='-', label=label_off)
plt.xlabel('High Voltage Source (V)')
ax_main.set_ylabel('Dark Rate (Hz)')
plt.title('PMT 7 (27σ threshold) ', loc='right', fontsize='medium')
ax_main.legend(loc='upper left', fontsize='medium', frameon=False)
# Remove the x-axis tick labels for the main plot since the x-axis is shared

ax_res.axhline(0, color='gray', linestyle='--') # Draw a horizontal line at y=0
ax_main.tick_params(axis='x', labelbottom=False)
ax_res.set_xlabel('High Voltage Source (V)')
ax_res.set_ylabel('Residuals (Hz)')
ax_res.grid(True, linestyle=':', alpha=0.7)
ax_res.legend(loc='lower left', fontsize='small', frameon=False)



# 3. Final Display
plt.tight_layout(rect=[0, 0, 1, 0.96]) # Adjust layout to make room for suptitle
plt.show()
# Out:
# 0.4694423133064731
# 0.6761110922952921
# 1.5729707964444728
# 1.6617948307808252
# 2.8301031849412652
# 3.8829880789966733
# 8.621805558475984
# 9.030374817934115
# 6.564910320451759
# 8.978250775794457
# 6.0935403329041264
# 8.836804683584987
# 6.915176669311904
# 9.788406482783538
# 9.381843223875535
# 12.384600627654613
# 3.4732060383216776
# 8.73096013745954
# 5.08329520110351
# 9.566953844413305
# 2.8774025699966614
# 11.006876119010903
# 3.537852595768527
# 12.669852062827406
# [1750 1800 1850 1900 1950 2000]
# [1750 1800 1850 1900 1950 2000]
# <>:218: SyntaxWarning: invalid escape sequence '\p'
# <>:230: SyntaxWarning: invalid escape sequence '\p'
# <>:244: SyntaxWarning: invalid escape sequence '\c'
# <>:257: SyntaxWarning: invalid escape sequence '\c'
# <>:218: SyntaxWarning: invalid escape sequence '\p'
# <>:230: SyntaxWarning: invalid escape sequence '\p'
# <>:244: SyntaxWarning: invalid escape sequence '\c'
# <>:257: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\holly\AppData\Local\Temp\ipykernel_28476\340658426.py:218: SyntaxWarning: invalid escape sequence '\p'
#   return f"{val:.1e} \pm {err:.1e}"
# C:\Users\holly\AppData\Local\Temp\ipykernel_28476\340658426.py:230: SyntaxWarning: invalid escape sequence '\p'
#   return (f"({scaled_val:.{n}f} \pm {scaled_err:.{n}f}) "
# C:\Users\holly\AppData\Local\Temp\ipykernel_28476\340658426.py:244: SyntaxWarning: invalid escape sequence '\c'
#   label_on += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_on, n=2)}'
# C:\Users\holly\AppData\Local\Temp\ipykernel_28476\340658426.py:257: SyntaxWarning: invalid escape sequence '\c'
#   label_off += f'\n$\chi^2_\\nu$ = {fmt_sig_figs(chi2nu_off, n=2)}'
# C:\Users\holly\AppData\Local\Temp\ipykernel_28476\340658426.py:278: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_res.legend(loc='lower left', fontsize='small', frameon=False)
